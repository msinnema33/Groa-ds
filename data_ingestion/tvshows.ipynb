# %% [markdown]
# # TV Series from IMDb

# %% [markdown]
# Download the `title.basics.tsv.gz` file from https://datasets.imdbws.com/ and extract `data.tsv` from archive

# %%
import pandas as pd
data = pd.read_csv('data.tsv', sep='\t', header=0)
data.head()
# Out:
#       tconst titleType            primaryTitle           originalTitle  \
# 0  tt0000001     short              Carmencita              Carmencita
# 1  tt0000002     short  Le clown et ses chiens  Le clown et ses chiens
# 2  tt0000003     short          Pauvre Pierrot          Pauvre Pierrot
# 3  tt0000004     short             Un bon bock             Un bon bock
# 4  tt0000005     short        Blacksmith Scene        Blacksmith Scene
#
#    isAdult startYear endYear runtimeMinutes                    genres
# 0        0      1894      \N              1         Documentary,Short
# 1        0      1892      \N              5           Animation,Short
# 2        0      1892      \N              4  Animation,Comedy,Romance
# 3        0      1892      \N             12           Animation,Short
# 4        0      1893      \N              1              Comedy,Short

# %%
# What type of movies there are?
data['titleType'].value_counts()
# Out:
# tvEpisode       4871527
# short            741249
# movie            551355
# video            265838
# tvSeries         184519
# tvMovie          121206
# tvMiniSeries      31099
# tvSpecial         29202
# videoGame         25559
# tvShort           12557
# Name: titleType, dtype: int64

# %%
# Save tv shows
series = data[data['titleType']=='tvSeries']
tvmovie = data[data['titleType']=='tvMovie']
miniseries = data[data['titleType']=='tvMiniSeries']
special = data[data['titleType']=='tvSpecial']
short = data[data['titleType']=='tvShort']

# Concatenate
frames = [series, tvmovie, miniseries, special, short]
tv = pd.concat(frames)
tv.shape
# Out:
# (378583, 9)

# %%
# We previously saved the movie ids without the 'tt' prefix
# Drop the 'tt' prefix, so that we have the same approach
ids = tv['tconst'].tolist()
tv_ids = []
for id in ids:
    tv_ids.append(id.lstrip('tt'))
tv['tconst']=tv_ids
tv.sample(3)
# Out:
#           tconst  titleType                            primaryTitle  \
# 5535962  7159236   tvSeries                                MNShorts
# 3728487  3115410  tvSpecial   Carly in Concert: Coming Around Again
# 2927022  1856400   tvSeries  Mit Arved Fuchs durch den Nordatlantik
#
#                                   originalTitle  isAdult startYear endYear  \
# 5535962                                MNShorts        0      2017    2017
# 3728487   Carly in Concert: Coming Around Again        0      1987      \N
# 2927022  Mit Arved Fuchs durch den Nordatlantik        0      2011      \N
#
#         runtimeMinutes       genres
# 5535962             \N    Talk-Show
# 3728487             \N        Music
# 2927022             43  Documentary

# %%
# Replace "\N" with NaN values
import numpy as np
tv = tv.replace('\\N', np.nan)
tv.sample(6)
# Out:
#            tconst  titleType  \
# 68867     0070272    tvMovie
# 1750369  11365256  tvSpecial
# 1602754  11106838   tvSeries
# 4830660   5603576   tvSeries
# 3081303   2016490   tvSeries
# 3120158   2056502  tvSpecial
#
#                                              primaryTitle  \
# 68867             The Men Who Made the Movies: King Vidor
# 1750369                                  Candy and Smiley
# 1602754                                           SweetyX
# 4830660                              Cherepashki Megablog
# 3081303                                           Hi-5 UK
# 3120158  9/11 Memorial from Ground Zero, Tenth Anniverary
#
#                                             originalTitle  isAdult startYear  \
# 68867             The Men Who Made the Movies: King Vidor        0      1973
# 1750369                                  Candy and Smiley        0       NaN
# 1602754                                           SweetyX        1      2017
# 4830660                              Cherepashki Megablog        0      2016
# 3081303                                           Hi-5 UK        0      2008
# 3120158  9/11 Memorial from Ground Zero, Tenth Anniverary        0      2011
#
#         endYear runtimeMinutes                  genres
# 68867       NaN             55   Biography,Documentary
# 1750369     NaN            NaN             Documentary
# 1602754     NaN            NaN                   Adult
# 4830660     NaN            NaN               Game-Show
# 3081303     NaN            NaN  Adventure,Family,Music
# 3120158     NaN            300             Documentary

# %%
tv.to_csv('tvshows.csv', sep='\t', index=False)

# %% [markdown]
# ***Insert into the DB using pgAdmin***
